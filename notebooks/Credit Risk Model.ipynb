# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.set_option('display.float_format',lambda x:'{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %%
df_customers=pd.read_csv("D:/Data Science/Machine Learning CodeBasics/1.ML Project Credit Risk Modelling/dataset/customers.csv")
df_loans=pd.read_csv("D:/Data Science/Machine Learning CodeBasics/1.ML Project Credit Risk Modelling/dataset/loans.csv")
df_bureau=pd.read_csv("D:/Data Science/Machine Learning CodeBasics/1.ML Project Credit Risk Modelling/dataset/bureau_data.csv")

# %%
df_customers.shape,df_loans.shape,df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df=pd.merge(df_customers,df_loans,on='cust_id')
df.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
# 3  ...     1747000        34940.00  314460          1397600
# 4  ...     4520000        90400.00  813600          3616000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
# 3                  6                1257839                      1031094
# 4                 28                1772334                      1032458
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
# 3      2019-07-24            2019-08-09    False
# 4      2019-07-24            2019-08-02    False
#
# [5 rows x 26 columns]

# %%
df1=pd.merge(df,df_bureau)
df1.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
# 3  ...     2019-07-24            2019-08-09   False                       3
# 4  ...     2019-07-24            2019-08-02   False                       4
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
# 3                         0                115                 15         87
# 4                         2                120                  0          0
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
# 3              5                        26
# 4              5                        10
#
# [5 rows x 33 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %%
df1['default']=df1['default'].astype(int)
df1.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %%
df1.head()

X=df1.drop('default',axis='columns')
y=df1['default']

X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.25,random_state=42)

df_train=pd.concat([X_train,y_train],axis='columns')
df_test=pd.concat([X_test,y_test],axis='columns')

df_train.head()
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
# 9040   C09041   42      M        Married          Salaried   1500000
# 13077  C13078   58      M        Married     Self-Employed   1817000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
# 9040                      2       Mortgage                        30
# 13077                     4          Owned                        29
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
# 43675    Chennai  ...     2023-12-04            2023-12-29
# 9040   Bangalore  ...     2020-06-18            2020-07-07
# 13077       Pune  ...     2020-11-12            2020-12-07
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# 32495                       3                         1               160
# 43675                       1                         1                54
# 9040                        3                         0                76
# 13077                       1                         2                60
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 12746                 20        118              4                        36
# 32495                 10         62              5                         5
# 43675                 12         67              4                         0
# 9040                   0          0              8                        87
# 13077                  0          0              1                        71
#
#        default
# 12746        0
# 32495        0
# 43675        0
# 9040         0
# 13077        0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### DATA CLEANING

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
mode_residence=df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train.residence_type.fillna(mode_residence,inplace=True)

# %%
df_test.residence_type.fillna(mode_residence,inplace=True)

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train.describe()
# Out:
#            age      income  number_of_dependants  years_at_current_address  \
# count 37500.00    37500.00              37500.00                  37500.00
# mean     39.54  2633326.16                  1.94                     16.00
# std       9.86  2623780.52                  1.54                      8.92
# min      18.00        0.00                  0.00                      1.00
# 25%      33.00   802000.00                  0.00                      8.00
# 50%      39.00  1885000.00                  2.00                     16.00
# 75%      46.00  3326250.00                  3.00                     24.00
# max      70.00 11999000.00                  5.00                     31.00
#
#         zipcode  sanction_amount  loan_amount  processing_fee        gst  \
# count  37500.00         37500.00     37500.00        37500.00   37500.00
# mean  418866.25       4699691.57   3996067.73        80290.68  719292.19
# std   169035.02       6257832.98   5371862.29       113128.14  966935.21
# min   110001.00             0.00         0.00            0.00       0.00
# 25%   302001.00       1142000.00    961000.00        19220.00  172980.00
# 50%   400001.00       2644000.00   2230000.00        44600.00  401400.00
# 75%   560001.00       5178000.00   4619000.00        92420.00  831420.00
# max   700001.00      52175000.00  47819000.00      5293543.52 8607420.00
#
#        net_disbursement  ...  principal_outstanding  \
# count          37500.00  ...               37500.00
# mean         3196854.19  ...             1333819.51
# std          4297489.83  ...             1213674.44
# min                0.00  ...                  -1.00
# 25%           768800.00  ...              422197.50
# 50%          1784000.00  ...              997427.50
# 75%          3695200.00  ...             1784879.00
# max         38255200.00  ...             5000000.00
#
#        bank_balance_at_application  number_of_open_accounts  \
# count                     37500.00                 37500.00
# mean                     986298.87                     2.50
# std                     1043145.01                     1.12
# min                           0.00                     1.00
# 25%                      287040.25                     1.00
# 50%                      665014.50                     3.00
# 75%                     1234062.75                     4.00
# max                     7846643.00                     4.00
#
#        number_of_closed_accounts  total_loan_months  delinquent_months  \
# count                   37500.00           37500.00           37500.00
# mean                        1.00              76.11               4.84
# std                         0.81              43.77               5.84
# min                         0.00               1.00               0.00
# 25%                         0.00              42.00               0.00
# 50%                         1.00              71.00               3.00
# 75%                         2.00             107.00               8.00
# max                         2.00             223.00              24.00
#
#        total_dpd  enquiry_count  credit_utilization_ratio  default
# count   37500.00       37500.00                  37500.00 37500.00
# mean       26.67           5.01                     43.42     0.09
# std        32.78           2.03                     29.39     0.28
# min         0.00           1.00                      0.00     0.00
# 25%         0.00           4.00                     18.00     0.00
# 50%        13.00           5.00                     39.00     0.00
# 75%        46.00           6.00                     67.00     0.00
# max       171.00           9.00                     99.00     1.00
#
# [8 rows x 21 columns]

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

columns_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03][['loan_amount','processing_fee']]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %%
df_train_1=df_train[(df_train.processing_fee/df_train.loan_amount)<0.03].copy()
df_train_1[(df_train_1.processing_fee/df_train_1.loan_amount)>0.03][['loan_amount','processing_fee']]
# Out:
# Empty DataFrame
# Columns: [loan_amount, processing_fee]
# Index: []

# %%
df_test_1=df_test[(df_test.processing_fee/df_test.loan_amount)<0.03].copy()
df_test_1.shape
# Out:
# (12497, 33)

# %%
for col in columns_categorical:
    print(col,"-->",df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %%
df_train_1[df_train_1.loan_purpose=="Personaal"]
# Out:
#       cust_id  age gender marital_status employment_status   income  \
# 16586  C16587   32      M        Married          Salaried  1128000
# 23615  C23616   34      F         Single          Salaried   347000
# 39066  C39067   44      M        Married     Self-Employed  1083000
# 20391  C20392   24      F         Single     Self-Employed  1760000
# 42874  C42875   34      M        Married     Self-Employed  3934000
# 25324  C25325   41      M        Married     Self-Employed  2742000
# 13007  C13008   36      M        Married     Self-Employed  6391000
# 20393  C20394   46      M        Married          Salaried  1649000
# 14926  C14927   45      M         Single          Salaried  1157000
# 6722   C06723   43      F         Single     Self-Employed   898000
# 44956  C44957   33      F        Married     Self-Employed  1584000
# 26766  C26767   45      M        Married          Salaried  2222000
# 15459  C15460   45      F        Married     Self-Employed   580000
# 6746   C06747   30      M        Married     Self-Employed  9996000
# 5227   C05228   44      F         Single     Self-Employed  3444000
# 4744   C04745   56      F        Married     Self-Employed   824000
# 12752  C12753   28      M         Single          Salaried   703000
# 6407   C06408   43      F        Married          Salaried   962000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 16586                     3       Mortgage                        10
# 23615                     0         Rented                        31
# 39066                     4       Mortgage                         6
# 20391                     0          Owned                        26
# 42874                     2         Rented                        26
# 25324                     3          Owned                        25
# 13007                     2         Rented                        18
# 20393                     3          Owned                        28
# 14926                     1          Owned                        26
# 6722                      0          Owned                        22
# 44956                     3          Owned                        23
# 26766                     2          Owned                        12
# 15459                     3         Rented                        17
# 6746                      2         Rented                        17
# 5227                      0       Mortgage                        10
# 4744                      3       Mortgage                        25
# 12752                     1          Owned                         2
# 6407                      5         Rented                        31
#
#             city  ... disbursal_date  installment_start_dt  \
# 16586     Jaipur  ...     2021-03-21            2021-04-02
# 23615      Delhi  ...     2021-12-02            2021-12-30
# 39066     Mumbai  ...     2023-06-19            2023-07-19
# 20391      Delhi  ...     2021-08-06            2021-08-30
# 42874     Jaipur  ...     2023-11-05            2023-11-29
# 25324     Mumbai  ...     2022-02-03            2022-02-09
# 13007    Lucknow  ...     2020-11-10            2020-11-29
# 20393    Kolkata  ...     2021-08-07            2021-08-13
# 14926    Lucknow  ...     2021-01-19            2021-02-01
# 6722     Chennai  ...     2020-03-26            2020-04-03
# 44956    Kolkata  ...     2024-01-20            2024-02-01
# 26766    Kolkata  ...     2022-03-27            2022-04-23
# 15459  Hyderabad  ...     2021-02-07            2021-02-22
# 6746     Chennai  ...     2020-03-26            2020-04-23
# 5227      Jaipur  ...     2020-01-31            2020-02-17
# 4744      Jaipur  ...     2020-01-13            2020-01-29
# 12752    Kolkata  ...     2020-11-01            2020-11-16
# 6407   Bangalore  ...     2020-03-14            2020-03-30
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 16586                       2                         0               101
# 23615                       2                         0                42
# 39066                       3                         1               108
# 20391                       4                         0                48
# 42874                       4                         2                70
# 25324                       2                         1                99
# 13007                       1                         2                49
# 20393                       3                         2               111
# 14926                       4                         1                77
# 6722                        2                         0                65
# 44956                       4                         1               107
# 26766                       1                         0                39
# 15459                       2                         2               109
# 6746                        2                         0                40
# 5227                        4                         0                94
# 4744                        2                         1                66
# 12752                       4                         0               144
# 6407                        1                         2                29
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 16586                  3         21              7                        20
# 23615                  0          0              3                        57
# 39066                  6         35              4                        45
# 20391                  8         48              9                        45
# 42874                 11         69              9                        64
# 25324                  8         44              6                        80
# 13007                  3         19              3                        37
# 20393                 10         62              5                        66
# 14926                  8         51              9                        25
# 6722                  11         62              3                         0
# 44956                 11         55              6                        62
# 26766                 23        119              4                        12
# 15459                  0          0              3                         1
# 6746                   0          0              2                        33
# 5227                  12         70              6                        18
# 4744                   0          0              2                        16
# 12752                  0          0              9                        35
# 6407                  12         66              3                        94
#
#        default
# 16586        0
# 23615        0
# 39066        0
# 20391        0
# 42874        0
# 25324        0
# 13007        0
# 20393        0
# 14926        0
# 6722         0
# 44956        0
# 26766        0
# 15459        0
# 6746         0
# 5227         0
# 4744         0
# 12752        0
# 6407         1
#
# [18 rows x 33 columns]

# %%
df_train_1['loan_purpose']=df_train_1['loan_purpose'].replace('Personaal','Personal')
df_test_1['loan_purpose']=df_test_1['loan_purpose'].replace('Personaal','Personal')
df_train_1.loan_purpose.unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %% [markdown]
# ### Explorattory Data Analysis(EDA)

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %%
sns.boxplot(df_train_1.age)
# Out:
# <Axes: ylabel='age'>

# %%
sns.kdeplot(df_train_1.age,fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(df_train_1.age,fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(df_train_1[df_train_1.default==0]['age'],fill=True,label="Default=0")
sns.kdeplot(df_train_1[df_train_1.default==1]['age'],fill=True,label="Default=1")
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# Insights
# 1. Orange graph is little bit to the left which indicates that people with young age are more likely to default

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
# 1. In remaining columns the distributions do not give any obvious insights
# 1. Why loan_amount and income did not give any signs of being strong predictors? May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# ### Feature Engineering

# %%
df_train_1["loan_to_income"]=round(df_train_1["loan_amount"]/df_train_1["income"],2)
df_test_1["loan_to_income"]=round(df_test_1["loan_amount"]/df_test_1["income"],2)
df_test_1["loan_to_income"].describe()
# Out:
# count   12497.00
# mean        1.55
# std         0.97
# min         0.30
# 25%         0.78
# 50%         1.16
# 75%         2.43
# max         4.59
# Name: loan_to_income, dtype: float64

# %%
sns.kdeplot(df_train_1[df_train_1.default==0]['loan_to_income'],fill=True,label="Default=0")
sns.kdeplot(df_train_1[df_train_1.default==1]['loan_to_income'],fill=True,label="Default=1")
# Out:
# <Axes: xlabel='loan_to_income', ylabel='Density'>

# %%
df_train_1[["delinquent_months","total_loan_months"]]
# Out:
#        delinquent_months  total_loan_months
# 12746                 20                152
# 32495                 10                160
# 43675                 12                 54
# 9040                   0                 76
# 13077                  0                 60
# ...                  ...                ...
# 28515                  0                 40
# 5558                  14                 52
# 45236                 11                130
# 49228                  0                 88
# 37784                 13                 17
#
# [37488 rows x 2 columns]

# %%
df_train_1["delinquency_ratio"]=round(df_train_1['delinquent_months']*100/df_train_1['total_loan_months'],1)

# %%
df_train_1[["delinquent_months","total_loan_months","delinquency_ratio"]].head(5)
# Out:
#        delinquent_months  total_loan_months  delinquency_ratio
# 12746                 20                152              13.20
# 32495                 10                160               6.20
# 43675                 12                 54              22.20
# 9040                   0                 76               0.00
# 13077                  0                 60               0.00

# %%
df_test_1["delinquency_ratio"]=round(df_test_1['delinquent_months']*100/df_test_1['total_loan_months'],1)

# %%
df_test_1["loan_to_income"]=round(df_test_1["loan_amount"]/df_test_1["income"],2)

# %%
sns.kdeplot(df_train_1[df_train_1.default==0]['delinquency_ratio'],fill=True,label="Default=0")
sns.kdeplot(df_train_1[df_train_1.default==1]['delinquency_ratio'],fill=True,label="Default=1")
# Out:
# <Axes: xlabel='delinquency_ratio', ylabel='Density'>

# %%
df_train_1['avg_dpd_per_delinquency']=np.where(
    df_train_1["delinquent_months"]!=0,
    df_train_1['total_dpd']/df_train_1["delinquent_months"].round(1),0)
df_train_1['avg_dpd_per_delinquency'].describe()
# Out:
# count   37488.00
# mean        3.28
# std         2.91
# min         0.00
# 25%         0.00
# 50%         4.33
# 75%         5.74
# max        10.00
# Name: avg_dpd_per_delinquency, dtype: float64

# %%
df_test_1['avg_dpd_per_delinquency']=np.where(
    df_test_1["delinquent_months"]!=0,
    df_test_1['total_dpd']/df_test_1["delinquent_months"].round(1),0)
df_test_1['avg_dpd_per_delinquency'].describe()
# Out:
# count   12497.00
# mean        3.34
# std         2.90
# min         0.00
# 25%         0.00
# 50%         4.40
# 75%         5.75
# max        10.00
# Name: avg_dpd_per_delinquency, dtype: float64

# %%
df_test_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
sns.kdeplot(df_train_1[df_train_1.default==0]['avg_dpd_per_delinquency'],fill=True,label="Default=0")
sns.kdeplot(df_train_1[df_train_1.default==1]['avg_dpd_per_delinquency'],fill=True,label="Default=1")
# Out:
# <Axes: xlabel='avg_dpd_per_delinquency', ylabel='Density'>

# %% [markdown]
# ### Feature Selection

# %%
df_train_2=df_train_1.drop(['cust_id','loan_id'],axis='columns')
df_test_2=df_test_1.drop(['cust_id','loan_id'],axis='columns')

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test_3 = df_test_1.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test_3.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_id', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64','float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  int64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  int64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  int64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  int64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  sanction_amount              37488 non-null  int64
#  13  processing_fee               37488 non-null  float64
#  14  gst                          37488 non-null  int64
#  15  net_disbursement             37488 non-null  int64
#  16  loan_tenure_months           37488 non-null  int64
#  17  principal_outstanding        37488 non-null  int64
#  18  bank_balance_at_application  37488 non-null  int64
#  19  number_of_open_accounts      37488 non-null  int64
#  20  number_of_closed_accounts    37488 non-null  int64
#  21  enquiry_count                37488 non-null  int64
#  22  credit_utilization_ratio     37488 non-null  int64
#  23  default                      37488 non-null  int64
#  24  loan_to_income               37488 non-null  float64
#  25  delinquency_ratio            37488 non-null  float64
#  26  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(4), int64(15), object(8)
# memory usage: 8.0+ MB

# %%
df_train_3[['default']]
# Out:
#        default
# 12746        0
# 32495        0
# 43675        0
# 9040         0
# 13077        0
# ...        ...
# 28515        0
# 5558         0
# 45236        1
# 49228        0
# 37784        1
#
# [37488 rows x 1 columns]

# %%
df_train_3['default'] = df_train_3['default'].astype(np.int32)
df_test_3['default'] = df_test_3['default'].astype(np.int32)

# %%
df_train_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  int64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  int64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  int64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  int64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  sanction_amount              37488 non-null  int64
#  13  processing_fee               37488 non-null  float64
#  14  gst                          37488 non-null  int64
#  15  net_disbursement             37488 non-null  int64
#  16  loan_tenure_months           37488 non-null  int64
#  17  principal_outstanding        37488 non-null  int64
#  18  bank_balance_at_application  37488 non-null  int64
#  19  number_of_open_accounts      37488 non-null  int64
#  20  number_of_closed_accounts    37488 non-null  int64
#  21  enquiry_count                37488 non-null  int64
#  22  credit_utilization_ratio     37488 non-null  int64
#  23  default                      37488 non-null  int32
#  24  loan_to_income               37488 non-null  float64
#  25  delinquency_ratio            37488 non-null  float64
#  26  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(4), int32(1), int64(14), object(8)
# memory usage: 7.9+ MB

# %%
df_test_3.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_id', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_test_3.select_dtypes(['int64','float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train=df_train_3.drop('default',axis='columns')
y_train=df_train_3['default']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale=df_train_3.select_dtypes(["int64","float64"]).columns

scaler=MinMaxScaler()
X_train[cols_to_scale]=scaler.fit_transform(X_train[cols_to_scale])
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37488.00              37488.00                  37488.00 37488.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.40                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37488.00               37488.00                     37488.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37488.00                   37488.00       37488.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  37488.00        37488.00           37488.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.51               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 37488.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.57
# max                       1.00

# %%
X_test=df_test_3.drop('default',axis='columns')
y_test=df_test_3['default']

cols_to_scale=df_test_3.select_dtypes(["int64","float64"]).columns

X_test[cols_to_scale]=scaler.fit_transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12497.00              12497.00                  12497.00 12497.00
# mean      0.42                  0.38                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.09     0.09              0.09
# std               0.12            0.12     0.12              0.12
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12497.00               12497.00                     12497.00
# mean                 0.38                   0.26                         0.13
# std                  0.23                   0.25                         0.14
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.04
# 50%                  0.34                   0.20                         0.09
# 75%                  0.55                   0.36                         0.17
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12497.00                   12497.00       12497.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  12497.00        12497.00           12497.00
# mean                       0.44            0.29               0.11
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12497.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.44
# 75%                       0.58
# max                       1.00

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df=pd.DataFrame()
    vif_df['Column']=data.columns
    vif_df['VIF']=[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X_train[cols_to_scale])
calculate_vif(X_test[cols_to_scale])#VIF Used to get MultiCollinearity between independent columns
# Out:
# C:\Users\somes\AppData\Roaming\Python\Python314\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# C:\Users\somes\AppData\Roaming\Python\Python314\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.81
# 1          number_of_dependants   2.72
# 2      years_at_current_address   3.43
# 3                       zipcode   3.80
# 4               sanction_amount 102.45
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   6.00
# 9         principal_outstanding  16.04
# 10  bank_balance_at_application   9.06
# 11      number_of_open_accounts   4.31
# 12    number_of_closed_accounts   2.38
# 13                enquiry_count   6.35
# 14     credit_utilization_ratio   2.93
# 15               loan_to_income   6.79
# 16            delinquency_ratio   1.99
# 17      avg_dpd_per_delinquency   2.98

# %%
features_to_drop_vif=['sanction_amount','processing_fee','gst','net_disbursement','principal_outstanding']

X_train_1=X_train.drop(features_to_drop_vif,axis='columns')
numeric_cols=X_train_1.select_dtypes(['int64','float64']).columns
numeric_cols
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_test_1=X_test.drop(features_to_drop_vif,axis='columns')
numeric=X_test.select_dtypes(['int64','float64']).columns
numeric
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
vif_df=calculate_vif(X_train_1[numeric_cols])
vif_df
# Out:
#                          Column  VIF
# 0                           age 5.43
# 1          number_of_dependants 2.73
# 2      years_at_current_address 3.40
# 3                       zipcode 3.78
# 4            loan_tenure_months 6.02
# 5   bank_balance_at_application 1.80
# 6       number_of_open_accounts 4.35
# 7     number_of_closed_accounts 2.37
# 8                 enquiry_count 6.38
# 9      credit_utilization_ratio 2.92
# 10               loan_to_income 4.56
# 11            delinquency_ratio 1.93
# 12      avg_dpd_per_delinquency 2.91

# %%
selected_numeric_features_vif=vif_df.Column.values
selected_numeric_features_vif
# Out:
# array(['age', 'number_of_dependants', 'years_at_current_address',
#        'zipcode', 'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'enquiry_count', 'credit_utilization_ratio', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'], dtype=object)

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
temp=pd.concat([X_train_1,y_train],axis=1)
temp.groupby('loan_purpose')['default'].agg(['count','sum'])
# Out:
#               count   sum
# loan_purpose
# Auto           7447   327
# Education      5620   559
# Home          11304  1734
# Personal      13117   603

# %%
def calculate_woe_iv(df,feature,target):
    grouped=df.groupby(feature)[target].agg(['count','sum'])
    grouped=grouped.rename(columns={'count':'total','sum':'good'})
    grouped['bad']=grouped['total']-grouped['good']

    total_good=grouped['good'].sum()
    total_bad=grouped['bad'].sum()

    grouped['good_pct']=grouped['good']/total_good
    grouped['bad_pct']=grouped['bad']/total_bad
    grouped['woe']=np.log(grouped['good_pct']/grouped['bad_pct'])
    grouped['IV']=(grouped['good_pct']-grouped['bad_pct'])*grouped['woe']

    grouped['woe']=grouped['woe'].replace([np.inf,-np.inf],0)
    grouped['IV']=grouped['IV'].replace([np.inf,-np.inf],0)

    total_iv=grouped["IV"].sum()
    
    return grouped,total_iv
grouped,total_iv=calculate_woe_iv(pd.concat([X_train_1,y_train],axis=1),'loan_purpose','default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   IV
# loan_purpose
# Auto           7447   327   7120      0.10     0.21 -0.72 0.08
# Education      5620   559   5061      0.17     0.15  0.16 0.00
# Home          11304  1734   9570      0.54     0.28  0.66 0.17
# Personal      13117   603  12514      0.19     0.37 -0.67 0.12

# %%
total_iv
# Out:
# np.float64(0.3691197842282755)

# %%
iv_values={}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype=='object':
        grouped_table,iv=calculate_woe_iv(pd.concat([X_train_1,y_train],axis=1),feature,'default')
        
    else:
        X_binned=pd.cut(X_train_1[feature],bins=10,labels=False)
        grouped_table,iv=calculate_woe_iv(pd.concat([X_binned,y_train],axis=1),feature,'default')
    iv_values[feature]=iv
    
iv_values
# Out:
# {'age': np.float64(0.0890689462679479),
#  'gender': np.float64(0.00047449502170914947),
#  'marital_status': np.float64(0.001129766845390142),
#  'employment_status': np.float64(0.003953046301722585),
#  'number_of_dependants': np.float64(0.0019380899135053508),
#  'residence_type': np.float64(0.246745268718145),
#  'years_at_current_address': np.float64(0.0020800513608156363),
#  'city': np.float64(0.0019059578709781529),
#  'state': np.float64(0.0019005589806779287),
#  'zipcode': np.float64(0.0016677413243392572),
#  'loan_purpose': np.float64(0.3691197842282755),
#  'loan_type': np.float64(0.16319324904149224),
#  'loan_tenure_months': np.float64(0.21893515090196278),
#  'bank_balance_at_application': np.float64(0.0063187993277516365),
#  'number_of_open_accounts': np.float64(0.08463134083005877),
#  'number_of_closed_accounts': np.float64(0.0011964272592421567),
#  'enquiry_count': np.float64(0.007864214085342608),
#  'credit_utilization_ratio': np.float64(2.352965568168245),
#  'loan_to_income': np.float64(0.476415456948364),
#  'delinquency_ratio': np.float64(0.716576108689321),
#  'avg_dpd_per_delinquency': np.float64(0.40176623566177694)}

# %%
pd.set_option('display.float_format',lambda x: '{:.3f}'.format(x))

iv_df=pd.DataFrame(list(iv_values.items()),columns=['Feature','IV'])
iv_df=iv_df.sort_values(by="IV",ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.353
# 19            delinquency_ratio 0.717
# 18               loan_to_income 0.476
# 20      avg_dpd_per_delinquency 0.402
# 10                 loan_purpose 0.369
# 5                residence_type 0.247
# 12           loan_tenure_months 0.219
# 11                    loan_type 0.163
# 0                           age 0.089
# 14      number_of_open_accounts 0.085
# 16                enquiry_count 0.008
# 13  bank_balance_at_application 0.006
# 3             employment_status 0.004
# 6      years_at_current_address 0.002
# 4          number_of_dependants 0.002
# 7                          city 0.002
# 8                         state 0.002
# 9                       zipcode 0.002
# 15    number_of_closed_accounts 0.001
# 2                marital_status 0.001
# 1                        gender 0.000

# %%
selected_features_iv=[feature for feature,iv in iv_values.items() if iv>0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# ### FEATURE ENCODING

# %%
X_train_reduced=X_train_1[selected_features_iv]
X_test_reduced=X_test_1[selected_features_iv]

# %%
X_train_reduced.head()
# Out:
#         age residence_type loan_purpose  loan_type  loan_tenure_months  \
# 12746 0.788          Owned         Home    Secured               0.415
# 32495 0.500          Owned    Education    Secured               0.830
# 43675 0.385       Mortgage         Home    Secured               0.491
# 9040  0.462       Mortgage    Education    Secured               0.642
# 13077 0.769          Owned     Personal  Unsecured               0.170
#
#        number_of_open_accounts  credit_utilization_ratio  loan_to_income  \
# 12746                    1.000                     0.364           0.415
# 32495                    0.667                     0.051           0.307
# 43675                    0.000                     0.000           0.759
# 9040                     0.667                     0.879           0.194
# 13077                    0.000                     0.717           0.047
#
#        delinquency_ratio  avg_dpd_per_delinquency
# 12746              0.132                    0.590
# 32495              0.062                    0.620
# 43675              0.222                    0.558
# 9040               0.000                    0.000
# 13077              0.000                    0.000

# %%
X_train_encoded=pd.get_dummies(X_train_reduced,drop_first=True)
X_test_encoded=pd.get_dummies(X_test_reduced,drop_first=True)

X_train_encoded.head()
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
# 9040  0.462               0.642                    0.667
# 13077 0.769               0.170                    0.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                     0.364           0.415              0.132
# 32495                     0.051           0.307              0.062
# 43675                     0.000           0.759              0.222
# 9040                      0.879           0.194              0.000
# 13077                     0.717           0.047              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                  True                  False
# 32495                    0.620                  True                  False
# 43675                    0.558                 False                  False
# 9040                     0.000                 False                  False
# 13077                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                   False               True                  False
# 32495                    True              False                  False
# 43675                   False               True                  False
# 9040                     True              False                  False
# 13077                   False              False                   True
#
#        loan_type_Unsecured
# 12746                False
# 32495                False
# 43675                False
# 9040                 False
# 13077                 True

# %% [markdown]
# <h3 align="center" style="color:blue">Model Training</h3>

# %% [markdown]
# ### Attempt 1
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.71      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.86      0.71      0.78      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.92      0.85      0.88     12497
# weighted avg       0.96      0.97      0.96     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.83      0.76      0.79      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.90      0.87      0.89     12497
# weighted avg       0.96      0.97      0.97     12497

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'C': np.logspace(-4, 4, 20),  # Logarithmically spaced values from 10^-4 to 10^4
    'solver': ['lbfgs', 'saga', 'liblinear', 'newton-cg']   # Algorithm to use in the optimization problem
}

# Create the Logistic Regression model
log_reg = LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 5-fold cross-validation
    verbose=2,
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters: {'solver': 'saga', 'C': np.float64(3792.690190732246)}
# Best Score: 0.7578060408520179
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.84      0.73      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.8, 'scale_pos_weight': 2, 'reg_lambda': 1.0, 'reg_alpha': 5.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Best Score: 0.7875566563372224
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.77      0.83      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.88      0.90      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %%
X_train_encoded.shape
# Out:
# (37488, 13)

# %% [markdown]
# ### Attempt 2
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# default
# 0    3223
# 1    3223
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.95      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.98      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.95      0.81     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# default
# 0    34198
# 1    34198
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# Define the objective function for Optuna
def objective(trial):
    param = {
        'C': trial.suggest_float('C', 1e-4, 1e4, log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])  # Class weights
    }

    model = LogisticRegression(**param, max_iter=10000)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2026-03-05 10:05:27,286] A new study created in memory with name: no-name-70339a68-07e9-4167-b8ba-d5eb34d7de46
# [I 2026-03-05 10:05:27,455] Trial 0 finished with value: 0.9282425387940872 and parameters: {'C': 0.01794731452520187, 'solver': 'newton-cg', 'tol': 0.011551329314113441, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9282425387940872.
# [I 2026-03-05 10:05:27,817] Trial 1 finished with value: 0.9424062867214434 and parameters: {'C': 0.1482243229025218, 'solver': 'saga', 'tol': 2.110529054382332e-06, 'class_weight': None}. Best is trial 1 with value: 0.9424062867214434.
# [I 2026-03-05 10:05:27,941] Trial 2 finished with value: 0.9339058230048676 and parameters: {'C': 0.02080236240846217, 'solver': 'saga', 'tol': 0.08648340397270156, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9424062867214434.
# [I 2026-03-05 10:05:28,078] Trial 3 finished with value: 0.9384687081552809 and parameters: {'C': 0.050762077202622304, 'solver': 'saga', 'tol': 0.06657087423822765, 'class_weight': None}. Best is trial 1 with value: 0.9424062867214434.
# [I 2026-03-05 10:05:28,239] Trial 4 finished with value: 0.9249581084872435 and parameters: {'C': 0.015234152408168392, 'solver': 'liblinear', 'tol': 0.025084891334665835, 'class_weight': None}. Best is trial 1 with value: 0.9424062867214434.
# [I 2026-03-05 10:05:28,513] Trial 5 finished with value: 0.9451808774444713 and parameters: {'C': 0.5783747194094354, 'solver': 'newton-cg', 'tol': 3.871697913875302e-05, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.9451808774444713.
# [I 2026-03-05 10:05:28,749] Trial 6 finished with value: 0.945383072234733 and parameters: {'C': 36.66781664625474, 'solver': 'newton-cg', 'tol': 0.00111479595076802, 'class_weight': None}. Best is trial 6 with value: 0.945383072234733.
# [I 2026-03-05 10:05:28,994] Trial 7 finished with value: 0.9456841138710447 and parameters: {'C': 87.98303309365775, 'solver': 'lbfgs', 'tol': 3.6187104597895348e-06, 'class_weight': None}. Best is trial 7 with value: 0.9456841138710447.
# [I 2026-03-05 10:05:29,322] Trial 8 finished with value: 0.9457852935931318 and parameters: {'C': 6.686336851961871, 'solver': 'liblinear', 'tol': 4.035693565561007e-05, 'class_weight': None}. Best is trial 8 with value: 0.9457852935931318.
# [I 2026-03-05 10:05:29,659] Trial 9 finished with value: 0.9456841731252194 and parameters: {'C': 1388.7580474496938, 'solver': 'liblinear', 'tol': 1.0383600010230913e-05, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.9457852935931318.
# [I 2026-03-05 10:05:29,802] Trial 10 finished with value: 0.7797916422416172 and parameters: {'C': 0.00010328386402565276, 'solver': 'liblinear', 'tol': 0.00018154484383012614, 'class_weight': None}. Best is trial 8 with value: 0.9457852935931318.
# [I 2026-03-05 10:05:30,128] Trial 11 finished with value: 0.9456841731252194 and parameters: {'C': 1254.6351399165594, 'solver': 'liblinear', 'tol': 2.1413469056827992e-05, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.9457852935931318.
# [I 2026-03-05 10:05:30,431] Trial 12 finished with value: 0.9456841731252194 and parameters: {'C': 5547.195471301045, 'solver': 'liblinear', 'tol': 2.322819959343822e-05, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.9457852935931318.
# [I 2026-03-05 10:05:30,704] Trial 13 finished with value: 0.945683535237392 and parameters: {'C': 20.887758471742817, 'solver': 'liblinear', 'tol': 0.00032645792006047946, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.9457852935931318.
# [I 2026-03-05 10:05:30,963] Trial 14 finished with value: 0.9458439548955231 and parameters: {'C': 4.331820949886334, 'solver': 'lbfgs', 'tol': 4.919677980308112e-06, 'class_weight': None}. Best is trial 14 with value: 0.9458439548955231.
# [I 2026-03-05 10:05:31,258] Trial 15 finished with value: 0.9458586673743682 and parameters: {'C': 4.7258067503896894, 'solver': 'lbfgs', 'tol': 1.2419780541432184e-06, 'class_weight': None}. Best is trial 15 with value: 0.9458586673743682.
# [I 2026-03-05 10:05:31,492] Trial 16 finished with value: 0.9458866272497484 and parameters: {'C': 2.4116214368768434, 'solver': 'lbfgs', 'tol': 2.367956763350781e-06, 'class_weight': None}. Best is trial 16 with value: 0.9458866272497484.
# [I 2026-03-05 10:05:31,636] Trial 17 finished with value: 0.8840203258415306 and parameters: {'C': 0.000537472338460837, 'solver': 'lbfgs', 'tol': 1.21688756086752e-06, 'class_weight': None}. Best is trial 16 with value: 0.9458866272497484.
# [I 2026-03-05 10:05:31,764] Trial 18 finished with value: 0.9366843781175094 and parameters: {'C': 0.8090950656563335, 'solver': 'lbfgs', 'tol': 0.003222805859765531, 'class_weight': None}. Best is trial 16 with value: 0.9458866272497484.
# [I 2026-03-05 10:05:32,014] Trial 19 finished with value: 0.9456841731252194 and parameters: {'C': 242.61300260358007, 'solver': 'lbfgs', 'tol': 1.1307183530171065e-06, 'class_weight': None}. Best is trial 16 with value: 0.9458866272497484.
# [I 2026-03-05 10:05:32,146] Trial 20 finished with value: 0.9143252261315231 and parameters: {'C': 0.0019286917040766238, 'solver': 'lbfgs', 'tol': 0.000131929309243522, 'class_weight': None}. Best is trial 16 with value: 0.9458866272497484.
# [I 2026-03-05 10:05:32,386] Trial 21 finished with value: 0.9458586107785406 and parameters: {'C': 4.467146962838519, 'solver': 'lbfgs', 'tol': 6.2987424048479406e-06, 'class_weight': None}. Best is trial 16 with value: 0.9458866272497484.
# [I 2026-03-05 10:05:32,643] Trial 22 finished with value: 0.9459021440568834 and parameters: {'C': 3.354109560627314, 'solver': 'lbfgs', 'tol': 4.724708804139409e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:32,861] Trial 23 finished with value: 0.9436542260064374 and parameters: {'C': 0.24614282936190618, 'solver': 'lbfgs', 'tol': 1.2354826500802211e-05, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:33,087] Trial 24 finished with value: 0.9458720330104405 and parameters: {'C': 2.4412130619096404, 'solver': 'lbfgs', 'tol': 2.521339513048208e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:33,333] Trial 25 finished with value: 0.9457392336081449 and parameters: {'C': 1.3175886903791516, 'solver': 'lbfgs', 'tol': 3.4172942835385427e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:33,562] Trial 26 finished with value: 0.9456838050735361 and parameters: {'C': 19.817529003028007, 'solver': 'lbfgs', 'tol': 1.0049306989834473e-05, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:33,762] Trial 27 finished with value: 0.9456694917589242 and parameters: {'C': 294.24998516873035, 'solver': 'lbfgs', 'tol': 6.093490055313463e-05, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:33,942] Trial 28 finished with value: 0.9458411643820573 and parameters: {'C': 1.2241163478899846, 'solver': 'lbfgs', 'tol': 0.0006182517445214189, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:34,221] Trial 29 finished with value: 0.9438887689205361 and parameters: {'C': 0.26932519298453617, 'solver': 'newton-cg', 'tol': 2.527852188427341e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:34,340] Trial 30 finished with value: 0.9157618808104875 and parameters: {'C': 0.004918620264954775, 'solver': 'lbfgs', 'tol': 0.006661743950907238, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:34,659] Trial 31 finished with value: 0.9458150279306986 and parameters: {'C': 6.8247269215899165, 'solver': 'lbfgs', 'tol': 1.02417187329635e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:34,873] Trial 32 finished with value: 0.9396284372094267 and parameters: {'C': 0.06251728850012343, 'solver': 'lbfgs', 'tol': 2.0742947929070706e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:35,228] Trial 33 finished with value: 0.9458730547493222 and parameters: {'C': 3.550574191024415, 'solver': 'saga', 'tol': 6.276097707613569e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:35,568] Trial 34 finished with value: 0.9456694640845992 and parameters: {'C': 66.53245047383746, 'solver': 'saga', 'tol': 6.149146861787429e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:35,904] Trial 35 finished with value: 0.9457987537409401 and parameters: {'C': 2.151059389367578, 'solver': 'saga', 'tol': 2.2300960594424496e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:36,224] Trial 36 finished with value: 0.939819129527871 and parameters: {'C': 0.06570156886075815, 'solver': 'saga', 'tol': 1.714557688034737e-05, 'class_weight': 'balanced'}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:36,541] Trial 37 finished with value: 0.9441087123252624 and parameters: {'C': 0.28339387928889437, 'solver': 'saga', 'tol': 7.307133569689018e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:36,823] Trial 38 finished with value: 0.9457128412771101 and parameters: {'C': 15.457076909169315, 'solver': 'saga', 'tol': 6.741493818110877e-05, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:37,144] Trial 39 finished with value: 0.9456841138710447 and parameters: {'C': 127.02876616558532, 'solver': 'newton-cg', 'tol': 2.1630963933950465e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:37,506] Trial 40 finished with value: 0.9354114098365157 and parameters: {'C': 0.02496558949264212, 'solver': 'saga', 'tol': 3.965537330513651e-06, 'class_weight': 'balanced'}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:37,807] Trial 41 finished with value: 0.9458877624856585 and parameters: {'C': 3.815551993462176, 'solver': 'lbfgs', 'tol': 1.983047473492947e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:38,105] Trial 42 finished with value: 0.9452392066607641 and parameters: {'C': 0.5510693355017144, 'solver': 'lbfgs', 'tol': 3.382869954476585e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:38,418] Trial 43 finished with value: 0.9458004251963802 and parameters: {'C': 9.298178844768593, 'solver': 'newton-cg', 'tol': 3.064756843414274e-05, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:38,725] Trial 44 finished with value: 0.9458425794188604 and parameters: {'C': 2.208074754273962, 'solver': 'lbfgs', 'tol': 1.1140639822739195e-05, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:39,138] Trial 45 finished with value: 0.9456839402035383 and parameters: {'C': 31.647881560642283, 'solver': 'saga', 'tol': 1.6873404276501985e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:39,387] Trial 46 finished with value: 0.9458572394144511 and parameters: {'C': 2.3080293003905297, 'solver': 'lbfgs', 'tol': 5.11503685373156e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:39,547] Trial 47 finished with value: 0.9046705908432836 and parameters: {'C': 0.41302587716300954, 'solver': 'lbfgs', 'tol': 0.02458815450219252, 'class_weight': 'balanced'}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:39,894] Trial 48 finished with value: 0.9456985983557645 and parameters: {'C': 47.662658997968975, 'solver': 'saga', 'tol': 1.4771473465051856e-05, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.
# [I 2026-03-05 10:05:40,191] Trial 49 finished with value: 0.9428319552702181 and parameters: {'C': 0.17011889005493352, 'solver': 'newton-cg', 'tol': 7.278247411056285e-06, 'class_weight': None}. Best is trial 22 with value: 0.9459021440568834.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9459021440568834
#   Params:
#     C: 3.354109560627314
#     solver: lbfgs
#     tol: 4.724708804139409e-06
#     class_weight: None
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2026-03-05 10:05:40,417] A new study created in memory with name: no-name-525bd909-e090-46d5-a1ec-20065a1a3d8e
# [I 2026-03-05 10:05:41,190] Trial 0 finished with value: 0.8890358026757816 and parameters: {'lambda': 0.18601257447648234, 'alpha': 1.2019631995606692, 'subsample': 0.7940860913770962, 'colsample_bytree': 0.7647041439628007, 'max_depth': 5, 'eta': 0.018609607720943177, 'gamma': 5.281911076383443, 'scale_pos_weight': 6.680718779463454, 'min_child_weight': 2, 'max_delta_step': 6}. Best is trial 0 with value: 0.8890358026757816.
# [I 2026-03-05 10:05:42,417] Trial 1 finished with value: 0.879521881973781 and parameters: {'lambda': 0.001137245712245103, 'alpha': 0.0748355134397258, 'subsample': 0.9798758393220818, 'colsample_bytree': 0.6482077573008528, 'max_depth': 9, 'eta': 0.012048216728786436, 'gamma': 2.503871642451918, 'scale_pos_weight': 6.375286569651115, 'min_child_weight': 8, 'max_delta_step': 10}. Best is trial 0 with value: 0.8890358026757816.
# [I 2026-03-05 10:05:43,001] Trial 2 finished with value: 0.9636896861210746 and parameters: {'lambda': 0.0022391406277294007, 'alpha': 0.02969556257763031, 'subsample': 0.9319948584780656, 'colsample_bytree': 0.5976786440681965, 'max_depth': 6, 'eta': 0.2894123280110608, 'gamma': 9.318888425687158, 'scale_pos_weight': 3.4853609503132335, 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 2 with value: 0.9636896861210746.
# [I 2026-03-05 10:05:44,029] Trial 3 finished with value: 0.9736434840637381 and parameters: {'lambda': 0.09269304556070906, 'alpha': 5.605241700394796, 'subsample': 0.43414647684828983, 'colsample_bytree': 0.8462904621024178, 'max_depth': 10, 'eta': 0.2488677814315796, 'gamma': 0.3686190404072487, 'scale_pos_weight': 1.9619113355543547, 'min_child_weight': 3, 'max_delta_step': 7}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:44,939] Trial 4 finished with value: 0.9619965195549914 and parameters: {'lambda': 0.3054530893698887, 'alpha': 0.009767438579660096, 'subsample': 0.8452190473997034, 'colsample_bytree': 0.740215064777589, 'max_depth': 9, 'eta': 0.08991157124041596, 'gamma': 8.025374526398327, 'scale_pos_weight': 7.875107899566283, 'min_child_weight': 4, 'max_delta_step': 8}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:45,677] Trial 5 finished with value: 0.9486261245567817 and parameters: {'lambda': 0.31545418074588133, 'alpha': 0.2181821974709461, 'subsample': 0.6135124716444641, 'colsample_bytree': 0.49206617384998785, 'max_depth': 6, 'eta': 0.12047211851506257, 'gamma': 8.644254577754985, 'scale_pos_weight': 7.398017042185508, 'min_child_weight': 10, 'max_delta_step': 10}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:46,577] Trial 6 finished with value: 0.9612328345162542 and parameters: {'lambda': 0.018589641580443402, 'alpha': 1.5021765450786388, 'subsample': 0.7266961054894898, 'colsample_bytree': 0.8916273309010634, 'max_depth': 7, 'eta': 0.08661135152274695, 'gamma': 2.6103523372291892, 'scale_pos_weight': 6.944560993867294, 'min_child_weight': 6, 'max_delta_step': 7}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:47,224] Trial 7 finished with value: 0.9536958185305693 and parameters: {'lambda': 0.0900167246501205, 'alpha': 0.001193728444983442, 'subsample': 0.43135944646340196, 'colsample_bytree': 0.5752523487958223, 'max_depth': 4, 'eta': 0.21608225800018804, 'gamma': 0.42437631409554477, 'scale_pos_weight': 7.526474163698143, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:48,079] Trial 8 finished with value: 0.9277558406918832 and parameters: {'lambda': 0.7967658811178859, 'alpha': 0.0016026595764656896, 'subsample': 0.7391318529601227, 'colsample_bytree': 0.4015595587911288, 'max_depth': 7, 'eta': 0.0545703168257172, 'gamma': 0.7753623041081326, 'scale_pos_weight': 5.850142756593976, 'min_child_weight': 9, 'max_delta_step': 4}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:49,023] Trial 9 finished with value: 0.9718685777762772 and parameters: {'lambda': 0.05607159999862963, 'alpha': 0.05600914553218518, 'subsample': 0.9506308222654749, 'colsample_bytree': 0.9641186100385742, 'max_depth': 10, 'eta': 0.16306854890774103, 'gamma': 2.157624450960528, 'scale_pos_weight': 6.6468240849349804, 'min_child_weight': 3, 'max_delta_step': 7}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:49,624] Trial 10 finished with value: 0.964615246201991 and parameters: {'lambda': 5.860397231594576, 'alpha': 3.73534231517015, 'subsample': 0.4023699299632361, 'colsample_bytree': 0.8599938695310626, 'max_depth': 3, 'eta': 0.299413587827081, 'gamma': 5.2916929573230576, 'scale_pos_weight': 1.3236702627422803, 'min_child_weight': 5, 'max_delta_step': 4}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:50,550] Trial 11 finished with value: 0.9682346113137824 and parameters: {'lambda': 0.0178476601026032, 'alpha': 9.967835651283375, 'subsample': 0.5922094287030824, 'colsample_bytree': 0.9699919368545493, 'max_depth': 10, 'eta': 0.1890438601049761, 'gamma': 2.9036375468894344, 'scale_pos_weight': 3.85141702989394, 'min_child_weight': 3, 'max_delta_step': 5}. Best is trial 3 with value: 0.9736434840637381.
# [I 2026-03-05 10:05:51,752] Trial 12 finished with value: 0.9748570231422539 and parameters: {'lambda': 0.024579262744045326, 'alpha': 0.2983091660898209, 'subsample': 0.5446669041376617, 'colsample_bytree': 0.9961991371337393, 'max_depth': 10, 'eta': 0.23682735922479164, 'gamma': 0.09141695418177942, 'scale_pos_weight': 9.756253214253555, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:52,787] Trial 13 finished with value: 0.9723240662469202 and parameters: {'lambda': 0.007558442143835654, 'alpha': 0.5365093973559939, 'subsample': 0.5233117246622823, 'colsample_bytree': 0.8362302719731155, 'max_depth': 8, 'eta': 0.242451217683328, 'gamma': 0.06017071288685294, 'scale_pos_weight': 9.98841906184673, 'min_child_weight': 1, 'max_delta_step': 2}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:53,486] Trial 14 finished with value: 0.9684555240662234 and parameters: {'lambda': 1.5281179089741381, 'alpha': 9.997456236942291, 'subsample': 0.5083024045703898, 'colsample_bytree': 0.98682819095486, 'max_depth': 9, 'eta': 0.26620918415209066, 'gamma': 3.9303587229993715, 'scale_pos_weight': 1.0252877519169274, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:54,230] Trial 15 finished with value: 0.9655784765508155 and parameters: {'lambda': 0.04505689226719423, 'alpha': 0.2864674247979859, 'subsample': 0.5019361634767678, 'colsample_bytree': 0.8956558823739276, 'max_depth': 10, 'eta': 0.23101358144361167, 'gamma': 7.212710943757919, 'scale_pos_weight': 9.707344480840465, 'min_child_weight': 4, 'max_delta_step': 0}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:55,199] Trial 16 finished with value: 0.9724556299544913 and parameters: {'lambda': 0.004068749427074073, 'alpha': 1.9646154152408777, 'subsample': 0.6296800626591433, 'colsample_bytree': 0.8008959924774123, 'max_depth': 8, 'eta': 0.19026060399797917, 'gamma': 1.343923901271968, 'scale_pos_weight': 4.2508104964706765, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:55,941] Trial 17 finished with value: 0.9719763096323857 and parameters: {'lambda': 0.012713386524075184, 'alpha': 0.01524797946967811, 'subsample': 0.453263079798068, 'colsample_bytree': 0.9190965298932678, 'max_depth': 8, 'eta': 0.267857789644014, 'gamma': 3.9168231267719182, 'scale_pos_weight': 2.3240652027122986, 'min_child_weight': 5, 'max_delta_step': 4}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:57,069] Trial 18 finished with value: 0.9745655408120036 and parameters: {'lambda': 0.03283998128739023, 'alpha': 0.46150254629166165, 'subsample': 0.5576052200185867, 'colsample_bytree': 0.6971097366573188, 'max_depth': 10, 'eta': 0.20315592413548653, 'gamma': 1.2844610988583338, 'scale_pos_weight': 4.891905122629289, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:58,018] Trial 19 finished with value: 0.9650506926999447 and parameters: {'lambda': 0.020797499592083202, 'alpha': 0.22575518759566707, 'subsample': 0.657475273328474, 'colsample_bytree': 0.6588609726957038, 'max_depth': 9, 'eta': 0.14721419240845496, 'gamma': 6.456988304306073, 'scale_pos_weight': 4.948198709976255, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:05:58,981] Trial 20 finished with value: 0.9714295243581118 and parameters: {'lambda': 0.005082116661435243, 'alpha': 0.6050471811374754, 'subsample': 0.555393661173029, 'colsample_bytree': 0.7074460118211693, 'max_depth': 8, 'eta': 0.19731518424952393, 'gamma': 1.7030384039321893, 'scale_pos_weight': 8.531161119701501, 'min_child_weight': 1, 'max_delta_step': 3}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:06:00,022] Trial 21 finished with value: 0.9743166507092232 and parameters: {'lambda': 0.04032970520934721, 'alpha': 3.494235233278425, 'subsample': 0.47813409338388413, 'colsample_bytree': 0.8078722503220025, 'max_depth': 10, 'eta': 0.2537903147661245, 'gamma': 1.3293858145278854, 'scale_pos_weight': 2.7625163151030487, 'min_child_weight': 2, 'max_delta_step': 6}. Best is trial 12 with value: 0.9748570231422539.
# [I 2026-03-05 10:06:01,066] Trial 22 finished with value: 0.9759423297782216 and parameters: {'lambda': 0.04017526485528229, 'alpha': 0.6165086434269776, 'subsample': 0.5781197710516395, 'colsample_bytree': 0.7787486992190004, 'max_depth': 10, 'eta': 0.213629382155966, 'gamma': 1.297336049754552, 'scale_pos_weight': 2.8833022795046, 'min_child_weight': 2, 'max_delta_step': 5}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:01,878] Trial 23 finished with value: 0.9697014367008775 and parameters: {'lambda': 0.03167634470899889, 'alpha': 0.7229143241305402, 'subsample': 0.5624985861116454, 'colsample_bytree': 0.549721412783077, 'max_depth': 9, 'eta': 0.21435442414843278, 'gamma': 3.7508502655042606, 'scale_pos_weight': 4.944828245101453, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:02,956] Trial 24 finished with value: 0.9747416478651777 and parameters: {'lambda': 0.009178651333691005, 'alpha': 0.10995209447775371, 'subsample': 0.677667273572814, 'colsample_bytree': 0.6691387491462175, 'max_depth': 10, 'eta': 0.1528678851837392, 'gamma': 1.2749476276366516, 'scale_pos_weight': 3.0367578644864954, 'min_child_weight': 2, 'max_delta_step': 5}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:03,869] Trial 25 finished with value: 0.9662839451221242 and parameters: {'lambda': 0.010566351268664535, 'alpha': 0.17013514017965745, 'subsample': 0.6578062521438028, 'colsample_bytree': 0.5032865951499512, 'max_depth': 9, 'eta': 0.16494288775300808, 'gamma': 3.2810578624995443, 'scale_pos_weight': 8.797523600523588, 'min_child_weight': 1, 'max_delta_step': 5}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:04,957] Trial 26 finished with value: 0.9736431474395449 and parameters: {'lambda': 0.0038215976061584554, 'alpha': 0.11029954580274023, 'subsample': 0.6992404417541527, 'colsample_bytree': 0.6332749328203298, 'max_depth': 10, 'eta': 0.12878005614857183, 'gamma': 1.795199008758566, 'scale_pos_weight': 2.7276911277277374, 'min_child_weight': 4, 'max_delta_step': 5}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:05,861] Trial 27 finished with value: 0.9729106630033718 and parameters: {'lambda': 0.00194886810032694, 'alpha': 0.044858102446030744, 'subsample': 0.7740695846917974, 'colsample_bytree': 0.7657470728605373, 'max_depth': 7, 'eta': 0.17757998517198462, 'gamma': 0.9314028710546889, 'scale_pos_weight': 3.2623036878461593, 'min_child_weight': 2, 'max_delta_step': 6}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:06,708] Trial 28 finished with value: 0.9706435096237981 and parameters: {'lambda': 0.17133386672109746, 'alpha': 0.003978635461470125, 'subsample': 0.6834672245527825, 'colsample_bytree': 0.693972248766272, 'max_depth': 8, 'eta': 0.14003482855481061, 'gamma': 4.624657906131975, 'scale_pos_weight': 1.8667118318461196, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:07,430] Trial 29 finished with value: 0.9659483765212761 and parameters: {'lambda': 0.006591570538209837, 'alpha': 1.0307836286899958, 'subsample': 0.8592578456940035, 'colsample_bytree': 0.7679924772806557, 'max_depth': 5, 'eta': 0.2268552585510315, 'gamma': 0.025274452626681487, 'scale_pos_weight': 4.402013480518265, 'min_child_weight': 2, 'max_delta_step': 8}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:08,396] Trial 30 finished with value: 0.9675913442798273 and parameters: {'lambda': 0.163059506428186, 'alpha': 0.09747917351451488, 'subsample': 0.5950414910624928, 'colsample_bytree': 0.9445746703640651, 'max_depth': 9, 'eta': 0.08822575225887301, 'gamma': 5.357012026878956, 'scale_pos_weight': 2.9679537385710413, 'min_child_weight': 7, 'max_delta_step': 4}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:09,647] Trial 31 finished with value: 0.974227902685175 and parameters: {'lambda': 0.024441187639619503, 'alpha': 0.4451220035027504, 'subsample': 0.5546886388008302, 'colsample_bytree': 0.707416152611991, 'max_depth': 10, 'eta': 0.17401328024889512, 'gamma': 1.0326240693463706, 'scale_pos_weight': 5.5400536132865765, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:10,731] Trial 32 finished with value: 0.9732623594259066 and parameters: {'lambda': 0.0562857942848293, 'alpha': 0.3785225994240875, 'subsample': 0.5388370890348192, 'colsample_bytree': 0.6639390455413764, 'max_depth': 10, 'eta': 0.2049097224817334, 'gamma': 2.0450195773694393, 'scale_pos_weight': 4.671289299434792, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:11,663] Trial 33 finished with value: 0.9738501141163379 and parameters: {'lambda': 0.011053093222598372, 'alpha': 0.13435921787533073, 'subsample': 0.6517061014468786, 'colsample_bytree': 0.6098849004816361, 'max_depth': 10, 'eta': 0.27864271562802445, 'gamma': 1.4659512836165234, 'scale_pos_weight': 3.7984924079574176, 'min_child_weight': 1, 'max_delta_step': 5}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:12,789] Trial 34 finished with value: 0.9738475787285162 and parameters: {'lambda': 0.0022369145716723124, 'alpha': 0.9819749276687553, 'subsample': 0.6068270535228155, 'colsample_bytree': 0.7363670847416788, 'max_depth': 9, 'eta': 0.23598421181061402, 'gamma': 0.6346230842359514, 'scale_pos_weight': 6.047965507650945, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:13,823] Trial 35 finished with value: 0.9675289690273715 and parameters: {'lambda': 0.0011648540813670122, 'alpha': 0.021238014667389206, 'subsample': 0.48712865802482247, 'colsample_bytree': 0.6822702979394825, 'max_depth': 9, 'eta': 0.11326088368865712, 'gamma': 2.336094289754212, 'scale_pos_weight': 5.2758061587612275, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:14,519] Trial 36 finished with value: 0.9664095354912433 and parameters: {'lambda': 0.08850635492946093, 'alpha': 0.07042457208340396, 'subsample': 0.5824977432879553, 'colsample_bytree': 0.6288140458499596, 'max_depth': 10, 'eta': 0.20892381344398497, 'gamma': 9.692539667883096, 'scale_pos_weight': 2.037965288132348, 'min_child_weight': 5, 'max_delta_step': 6}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:15,343] Trial 37 finished with value: 0.9130706768382376 and parameters: {'lambda': 0.027439776349258403, 'alpha': 0.03809203817828293, 'subsample': 0.739465379457907, 'colsample_bytree': 0.5366166831218568, 'max_depth': 5, 'eta': 0.034680670449565784, 'gamma': 3.059916322372291, 'scale_pos_weight': 3.664756301986603, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:16,499] Trial 38 finished with value: 0.9748873263568925 and parameters: {'lambda': 0.2641382922129649, 'alpha': 2.184985904596789, 'subsample': 0.630905032844092, 'colsample_bytree': 0.740190530887178, 'max_depth': 10, 'eta': 0.2540103990349043, 'gamma': 0.5076618171213076, 'scale_pos_weight': 4.169631430519482, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:17,596] Trial 39 finished with value: 0.9749017097166938 and parameters: {'lambda': 0.3010006321962482, 'alpha': 2.224945609278103, 'subsample': 0.8131308584580417, 'colsample_bytree': 0.8032642645296696, 'max_depth': 9, 'eta': 0.2605490512692196, 'gamma': 0.479227077985164, 'scale_pos_weight': 4.240233055225521, 'min_child_weight': 4, 'max_delta_step': 7}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:18,696] Trial 40 finished with value: 0.9750775102349634 and parameters: {'lambda': 0.44962672378967705, 'alpha': 2.0001140461833242, 'subsample': 0.8692939166977016, 'colsample_bytree': 0.807053715019226, 'max_depth': 9, 'eta': 0.2570172837024693, 'gamma': 0.44458235456603923, 'scale_pos_weight': 4.09117548511645, 'min_child_weight': 4, 'max_delta_step': 9}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:19,797] Trial 41 finished with value: 0.9748292717708255 and parameters: {'lambda': 0.47374651661205497, 'alpha': 2.0423021017093017, 'subsample': 0.8631220423727786, 'colsample_bytree': 0.810711735705473, 'max_depth': 9, 'eta': 0.25655529171894254, 'gamma': 0.3910003130393105, 'scale_pos_weight': 4.094867202882892, 'min_child_weight': 4, 'max_delta_step': 9}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:20,867] Trial 42 finished with value: 0.974887603820251 and parameters: {'lambda': 1.3015934118386157, 'alpha': 3.075254361187408, 'subsample': 0.9213038119480518, 'colsample_bytree': 0.8571320972128442, 'max_depth': 9, 'eta': 0.2766791341809479, 'gamma': 0.003900060736673927, 'scale_pos_weight': 3.3688808160534682, 'min_child_weight': 4, 'max_delta_step': 10}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:21,787] Trial 43 finished with value: 0.973995034518742 and parameters: {'lambda': 1.5577477826040054, 'alpha': 3.317314940560421, 'subsample': 0.8959470771421709, 'colsample_bytree': 0.8644787527772155, 'max_depth': 8, 'eta': 0.2871149299571607, 'gamma': 0.7538580119644421, 'scale_pos_weight': 3.4104314357724017, 'min_child_weight': 5, 'max_delta_step': 10}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:22,630] Trial 44 finished with value: 0.9699210077156462 and parameters: {'lambda': 0.7063237865566762, 'alpha': 5.755696768518899, 'subsample': 0.9676465890939944, 'colsample_bytree': 0.7859642950894998, 'max_depth': 6, 'eta': 0.29973398786129024, 'gamma': 0.340739322350637, 'scale_pos_weight': 4.491938657953833, 'min_child_weight': 6, 'max_delta_step': 9}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:23,622] Trial 45 finished with value: 0.9753571606123256 and parameters: {'lambda': 2.0723840074183895, 'alpha': 1.6360771258526121, 'subsample': 0.8144156047197671, 'colsample_bytree': 0.7391176934227123, 'max_depth': 9, 'eta': 0.2723003365591978, 'gamma': 0.7226786428911496, 'scale_pos_weight': 2.3878154517651398, 'min_child_weight': 7, 'max_delta_step': 8}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:24,436] Trial 46 finished with value: 0.9715499727355456 and parameters: {'lambda': 5.996652222186025, 'alpha': 5.3894320755300535, 'subsample': 0.806780056535891, 'colsample_bytree': 0.8366632978326886, 'max_depth': 7, 'eta': 0.2778236867867903, 'gamma': 1.9667199266056414, 'scale_pos_weight': 2.406706036161276, 'min_child_weight': 7, 'max_delta_step': 7}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:25,162] Trial 47 finished with value: 0.9716542301226854 and parameters: {'lambda': 3.0545463725870103, 'alpha': 1.271446597551851, 'subsample': 0.9994670393638573, 'colsample_bytree': 0.8888206999202252, 'max_depth': 9, 'eta': 0.26789528539445295, 'gamma': 2.570208236831828, 'scale_pos_weight': 1.7811992938259746, 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:26,134] Trial 48 finished with value: 0.973232146247699 and parameters: {'lambda': 1.2462736198829547, 'alpha': 5.912651970530468, 'subsample': 0.9276203810465152, 'colsample_bytree': 0.8247993705195137, 'max_depth': 8, 'eta': 0.2813190007487931, 'gamma': 0.8668487281289243, 'scale_pos_weight': 3.3289489665375207, 'min_child_weight': 8, 'max_delta_step': 8}. Best is trial 22 with value: 0.9759423297782216.
# [I 2026-03-05 10:06:26,991] Trial 49 finished with value: 0.9735994851657667 and parameters: {'lambda': 3.333983464300016, 'alpha': 1.5906866426611108, 'subsample': 0.8152809540950329, 'colsample_bytree': 0.8634263381094761, 'max_depth': 7, 'eta': 0.22460189004973558, 'gamma': 0.10845320058856649, 'scale_pos_weight': 2.527114077637429, 'min_child_weight': 7, 'max_delta_step': 8}. Best is trial 22 with value: 0.9759423297782216.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9759423297782216
#   Params:
#     lambda: 0.04017526485528229
#     alpha: 0.6165086434269776
#     subsample: 0.5781197710516395
#     colsample_bytree: 0.7787486992190004
#     max_depth: 10
#     eta: 0.213629382155966
#     gamma: 1.297336049754552
#     scale_pos_weight: 2.8833022795046
#     min_child_weight: 2
#     max_delta_step: 5
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98     11423
#            1       0.70      0.86      0.77      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.84      0.91      0.87     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.        , 0.        , 0.        , 0.00008754, 0.00008754]),
#  array([0.        , 0.0009311 , 0.16014898, 0.16014898, 0.17504655]),
#  array([       inf, 1.        , 0.99942846, 0.99942618, 0.99928779]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# 0.983647451782651

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Model Evaluation : Rankordering, KS statistic, Gini coeff

# %%
probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth': y_test,
    'Default Probability': probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
# 19205              0                0.522
# 15514              0                0.000
# 30367              0                0.006

# %%
df_eval['Decile'] = pd.qcut(df_eval['Default Probability'], 10, labels=False, duplicates='drop')
df_eval.head(3)
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.522       8
# 15514              0                0.000       2
# 30367              0                0.006       6

# %%
df_eval[df_eval.Decile==8]['Default Probability'].describe()
# Out:
# count   1250.000
# mean       0.479
# std        0.182
# min        0.210
# 25%        0.311
# 50%        0.460
# 75%        0.631
# max        0.816
# Name: Default Probability, dtype: float64

# %%
df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
    'Minimum Probability': x['Default Probability'].min(),
    'Maximum Probability': x['Default Probability'].max(),
    'Events': x['Default Truth'].sum(),
    'Non-events': x['Default Truth'].count() - x['Default Truth'].sum(),    
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
# C:\Users\somes\AppData\Local\Temp\ipykernel_10396\4037021561.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.028   5.000    1245.000
# 7       7                0.028                0.209  10.000    1239.000
# 8       8                0.210                0.816 161.000    1089.000
# 9       9                0.816                1.000 898.000     352.000

# %%
df_decile['Event Rate'] = df_decile['Events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile['Non-event Rate'] = df_decile['Non-events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.028   5.000    1245.000
# 7       7                0.028                0.209  10.000    1239.000
# 8       8                0.210                0.816 161.000    1089.000
# 9       9                0.816                1.000 898.000     352.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.400          99.600
# 7       0.801          99.199
# 8      12.880          87.120
# 9      71.840          28.160

# %%
df_decile = df_decile.sort_values(by='Decile', ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.816                1.000 898.000     352.000
# 1       8                0.210                0.816 161.000    1089.000
# 2       7                0.028                0.209  10.000    1239.000
# 3       6                0.004                0.028   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      71.840          28.160
# 1      12.880          87.120
# 2       0.801          99.199
# 3       0.400          99.600
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile['Cum Events'] =  df_decile['Events'].cumsum()
df_decile['Cum Non-events'] =  df_decile['Non-events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.816                1.000 898.000     352.000
# 1       8                0.210                0.816 161.000    1089.000
# 2       7                0.028                0.209  10.000    1239.000
# 3       6                0.004                0.028   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events
# 0      71.840          28.160     898.000         352.000
# 1      12.880          87.120    1059.000        1441.000
# 2       0.801          99.199    1069.000        2680.000
# 3       0.400          99.600    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate'] = df_decile['Cum Events'] * 100 / df_decile['Events'].sum()
df_decile['Cum Non-event Rate'] = df_decile['Cum Non-events']*100 / df_decile['Non-events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.816                1.000 898.000     352.000
# 1       8                0.210                0.816 161.000    1089.000
# 2       7                0.028                0.209  10.000    1239.000
# 3       6                0.004                0.028   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.840          28.160     898.000         352.000          83.613
# 1      12.880          87.120    1059.000        1441.000          98.603
# 2       0.801          99.199    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.082
# 1              12.615
# 2              23.461
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS'] = abs(df_decile['Cum Event Rate'] - df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.816                1.000 898.000     352.000
# 1       8                0.210                0.816 161.000    1089.000
# 2       7                0.028                0.209  10.000    1239.000
# 3       6                0.004                0.028   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.840          28.160     898.000         352.000          83.613
# 1      12.880          87.120    1059.000        1441.000          98.603
# 2       0.801          99.199    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.082 80.531
# 1              12.615 85.988
# 2              23.461 76.073
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %%
gini_coefficient = 2 * area - 1

print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.983647451782651
# Gini Coefficient: 0.967294903565302

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.548              0.000
# 15514                     0.323           0.219              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
from joblib import dump

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(model_data, 'D:\\Data Science\\Machine Learning CodeBasics\\1.ML Project Credit Risk Modelling\\models\\model_data.joblib')
# Out:
# ['D:\\Data Science\\Machine Learning CodeBasics\\1.ML Project Credit Risk Modelling\\models\\model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[-0.03409505,  0.61556135,  1.18377969, 15.94921952, 17.35574901,
#          13.74426575,  2.0404369 , -1.84469162,  1.8526285 ,  1.01048885,
#          -3.42981922,  1.0531607 ,  1.0531607 ]]),
#  array([-20.77869302]))
